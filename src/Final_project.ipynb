# %% [markdown]
# # Final Project
#
#
# Team's alias: `chadnosac`
# Dataset: `Amazone Sales Dataset (Kaggle)`
#
# ## Introduction
# The dataset we'll be using has information on over 1000 products sold by Amazon, like their names, categories, prices, ratings, and reviews from the region India (the currency used in the dataset is Rupee). Our objective are to clean and prepare the data due to the raw data being very unorganized and sk some meaningful questions that can be answered to better understand the data.
#
# ---
#
# ## Team Members' Information
#
# | Full name              | Students' ID       |
# |-----------             |--------------      |
# |    **Bùi Nguyên Hanh**     |      21127606      |
# |    **Nguyễn Cao Sơn**      |      21127159      |

# %% [markdown]
# ## Importing Libraries

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data collection

# %%
amazon_df = pd.read_csv("../data/amazon.csv")
amazon_df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# ## Data Cleaning & Preparation

# %%
# number of rows and columns
amazon_df.shape
# Out:
# (1465, 16)

# %%
# dataframe's information
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# ### Columns description

# %% [markdown]
# `product_id` : Product ID
#
# `product_name` : Name of the Product
#
# `category` : Category of the Product
#
# `discounted_price` : Discounted Price of the Product
#
# `actual_price` : Actual Price of the Product
#
# `discount_percentage` : Percentage of Discount for the Product
#
# `rating` : Rating of the Product
#
# `rating_count` : Number of people who voted for the Amazon rating
#
# `about_product` : Description about the Product
#
# `user_id` : ID of the user who wrote review for the Product
#
# `user_name` : Name of the user who wrote review for the Product
#
# `review_id` : ID of the user review
#
# `review_title` : Short review
#
# `review_content` : Long review
#
# `img_link` : Image Link of the Product
#
# `product_link` : Official Website Link of the Product

# %% [markdown]
# ### Check for missing values

# %%
print(amazon_df.isna().sum())
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# As you can see there're 2 missing values in attribute `rating_count`, so i'm gonna remove it.

# %%
amazon_df.dropna(subset=['rating_count'], inplace=True)
print(amazon_df.isna().sum())
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# Changing the data type of `discounted price`, `actual price` and `discount percentage`

# %%
amazon_df['discounted_price'] = amazon_df['discounted_price'].str.replace('₹', '').str.replace(',', '').astype(float)
amazon_df['actual_price'] = amazon_df['actual_price'].str.replace('₹', '').str.replace(',', '').astype(float)
amazon_df['discount_percentage'] = amazon_df['discount_percentage'].str.replace('%','').astype(float)/100

# %%
amazon_df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage rating rating_count  \
# 0        1099.0                 0.64    4.2       24,269
# ...

# %%
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1463 non-null   object
#  1   product_name         1463 non-null   object
#  2   category             1463 non-null   object
#  3   discounted_price     1463 non-null   float64
#  4   actual_price         1463 non-null   float64
#  5   discount_percentage  1463 non-null   float64
#  6   rating               1463 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1463 non-null   object
#  9   user_id              1463 non-null   object
#  10  user_name            1463 non-null   object
#  11  review_id            1463 non-null   object
#  12  review_title         1463 non-null   object
#  13  review_content       1463 non-null   object
#  14  img_link             1463 non-null   object
# ...

# %% [markdown]
# There's something weird about attribute `rating`, i'll show you

# %%
amazon_df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 4.8      3
# 3.2      2
# 2.8      2
# 3.0      2
# 5.0      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %% [markdown]
# There's a row in dataset contains a special character `|`, i will exclude it

# %%
amazon_df = amazon_df[amazon_df['rating'].apply(lambda x: '|' not in str(x))]
amazon_df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage rating rating_count  \
# 0        1099.0                 0.64    4.2       24,269
# ...

# %%
amazon_df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 4.8      3
# 3.2      2
# 5.0      2
# 3.0      2
# 2.8      2
# 2.3      1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %% [markdown]
# Changing the data type of rating count and rating

# %%
amazon_df['rating'] = amazon_df['rating'].astype('float64')
amazon_df['rating_count'] = amazon_df['rating_count'].str.replace(',', '').astype('float64')
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1462 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1462 non-null   object
#  1   product_name         1462 non-null   object
#  2   category             1462 non-null   object
#  3   discounted_price     1462 non-null   float64
#  4   actual_price         1462 non-null   float64
#  5   discount_percentage  1462 non-null   float64
#  6   rating               1462 non-null   float64
#  7   rating_count         1462 non-null   float64
#  8   about_product        1462 non-null   object
#  9   user_id              1462 non-null   object
#  10  user_name            1462 non-null   object
#  11  review_id            1462 non-null   object
#  12  review_title         1462 non-null   object
#  13  review_content       1462 non-null   object
#  14  img_link             1462 non-null   object
# ...

# %% [markdown]
# ### Checking duplicate

# %%
amazon_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Numerical analysis

# %%
numeric_columns = ['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']
amazon_numeric = amazon_df[numeric_columns].copy()
amazon_numeric.head()
# Out:
#    discounted_price  actual_price  discount_percentage  rating  rating_count
# 0             399.0        1099.0                 0.64     4.2       24269.0
# 1             199.0         349.0                 0.43     4.0       43994.0
# 2             199.0        1899.0                 0.90     3.9        7928.0
# 3             329.0         699.0                 0.53     4.2       94363.0
# 4             154.0         399.0                 0.61     4.2       16905.0

# %%
amazon_numeric.describe().round(1)
# Out:
#        discounted_price  actual_price  discount_percentage  rating  \
# count            1462.0        1462.0               1462.0  1462.0
# mean             3130.0        5453.1                  0.5     4.1
# std              6950.5       10884.5                  0.2     0.3
# min                39.0          39.0                  0.0     2.0
# 25%               325.0         800.0                  0.3     4.0
# 50%               799.0        1670.0                  0.5     4.1
# 75%              1999.0        4321.2                  0.6     4.3
# max             77990.0      139900.0                  0.9     5.0
#
#        rating_count
# count        1462.0
# mean        18307.4
# std         42766.1
# min             2.0
# 25%          1191.5
# 50%          5179.0
# 75%         17342.2
# max        426973.0

# %% [markdown]
# ### Describe the correlation between numeric features in the dataset

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(amazon_numeric.corr(), cmap='crest', center=0, annot=True, fmt='.2f') 
plt.yticks(rotation=0)
plt.title('Correlation between numeric features', fontweight='bold')
plt.show()

# %%
df1 = amazon_df.copy()
plt.figure(figsize=(8,4))
sns.scatterplot(data=df1, x='actual_price',y='discounted_price')
plt.xlabel('Actual Price (Rupee India)', fontweight='bold')
plt.ylabel('Discounted Price (Rupee India)', fontweight='bold')
x = df1['actual_price']
y = df1['discounted_price']
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')

plt.show()

# %% [markdown]
# Categories on the e-commerce site **Amazon** are organized in order of relevance; categories with more relevance to the product are placed first, and vice versa. So, I add two new columns, one labeled `main_category` for the category in the first position and another labeled `sub_category` for the category in the last position.

# %%
amazon_df['main_category'] = amazon_df['category'].str.split('|').str[0]
amazon_df['sub_category'] = amazon_df['category'].str.split('|').str[-1]
amazon_df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
# ...

# %% [markdown]
# ## Asking/Answering question

# %% [markdown]
# **Question 1:** Based on the quantity of products, what can be inferred from the top 30 primary categories and top 30 subcategories?

# %%
main_category_counts = amazon_df['main_category'].value_counts()[:30]
categories = main_category_counts.index
counts = main_category_counts.values

plt.figure(figsize=(15, 8))
sns.barplot(x=categories, y=counts, palette='turbo')
plt.xticks(rotation=30)
plt.ylabel('Counts',fontweight='bold')
plt.xlabel(None)
plt.title('Number of Products per Main Category',fontweight='bold')
plt.show()

# %% [markdown]
# - Electronics, Computers & Accessories, and Home & Kitchen are the top three key categories. This indicates that consumers like these categories.The relatively small quantity of goods in the other three primary categories suggests that these categories are not as well-liked as the top three.
# -  Office Products, Musical Instruments, Home Improvement, Toys & Games, Car & Motorbike, and Health & Personal Care have a very small number of products, which may suggest that these categories have less demand.
# - By analyzing the data, companies may get insight into the state of the industry and spot growth prospects in certain product categories.

# %%
sub_category_counts = amazon_df['sub_category'].value_counts()[:30]
categories = sub_category_counts.index
counts = sub_category_counts.values

colors = sns.color_palette('pastel', len(categories))
plt.figure(figsize=(15, 10))
bar_plot =sns.barplot(x=categories, y=counts, palette=colors)
plt.ylabel('Counts',fontweight='bold')
plt.xlabel(None)
plt.title('Number of Products per Sub Category',fontweight='bold')
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.legend(bar_plot.patches, categories, title='Sub Categories', loc='upper right')
plt.show()

# %% [markdown]
# - Smartwatches, smartphones, smart TVs, in-ear headphones, USB cables, and remote controllers make up the top six category. These are the most well-liked subcategories, therefore companies should concentrate on offering goods in these areas to get clients.
# - The information reveals that the top 30 categories include a wide variety of subcategories, such as home electronics, personal items, and kitchen equipment. This emphasizes how crucial it is to provide a range of items in order to meet the various demands and tastes of customers.

# %% [markdown]
# ----
# **Question 2:** Is there a specific relationship between the actual price and the selling price after discounts?

# %%
#Top 5 Most Expensive Products Before Discount
df1 = amazon_df.copy()
plt.figure(figsize=(15, 6))
sns.barplot(data=df1.sort_values('actual_price', ascending=False).head(5), x='actual_price', y='product_name',palette='rocket')

plt.title('Top 5 Most Expensive Products Before Discount', fontweight='bold')
plt.xlabel('Discounted Price (Rupee India)', fontweight='bold')
plt.ylabel(None)
#Top 5 Most Expensive Products After Discount
df1 = amazon_df.copy()
plt.figure(figsize=(15, 4))
sns.barplot(data=df1.sort_values('discounted_price', ascending=False).head(5), x='discounted_price', y='product_name',palette='rocket')

plt.title('Top 5 Most Expensive Products After Discount', fontweight='bold')
plt.xlabel('Discounted Price (Rupee India)', fontweight='bold')
plt.ylabel(None)

plt.show()

# %%
# Top 5 Cheapest Products Before Discount
df1 = amazon_df.copy()
plt.figure(figsize=(8, 8))
sns.barplot(data=df1.sort_values('actual_price').head(5), x='actual_price', y='product_name',palette='rocket')

plt.title('Top 5 Cheapest Products Before Discount', fontweight='bold')
plt.xlabel('Discounted Price (Rupee India)', fontweight='bold')
plt.ylabel(None)

#Top 5 Cheapest Products After Discount
df1 = amazon_df.copy()
plt.figure(figsize=(8, 8))
sns.barplot(data=df1.sort_values('discounted_price').head(5), x='discounted_price', y='product_name',palette='rocket')

plt.title('Top 5 Cheapest Products After Discount', fontweight='bold')
plt.xlabel('Discounted Price (Rupee India)', fontweight='bold')
plt.ylabel(None)

plt.show()

# %% [markdown]
# - We can see a link between the selling price after reductions and the real price by looking at the bar chart. Discounts on items with higher beginning costs are often greater than those on products with lower initial prices. The amount of the discount or alluring incentive for clients is shown by the difference between the selling price before the discount and the selling price after the discount.
# - A few goods stand out as prominent outliers, meaning their real selling price and after-discount selling price varies significantly and may be much higher or cheaper than those of other products. It would be beneficial to look at these items further in order to have a deeper understanding of the marketing strategy and plan, since this might be the result of unique discount techniques or product peculiarities.
# - Products with lower discounts may need a stronger marketing strategy to generate consumer interest.

# %% [markdown]
# ----
# **Question 3:** Is there a consistent distribution of ratings for every product category? Or do items in the same category differ greatly from one another?
#
# **Meaning of this question:**
#
# - The analysis of customer satisfaction with various product categories and their respective quality levels is the relevance of this question.
# - Sellers can collect these insight to concentrate on enhancing or improving the quality of items in lower-rated categories, or optimize marketing and sales tactics for products in higher-rated categories.

# %%
# Rating Distribution
df1 = amazon_df.copy()
plt.figure(figsize=(10,4))
sns.boxplot(data=df1, x='rating', y='main_category', palette='turbo')

plt.xlabel('Rating', fontweight='bold')
plt.ylabel('Product Main Category', fontweight='bold')
plt.title('Rating Distribution by Product Main Category', fontweight='bold')

plt.show()

# %% [markdown]
# Some insights can be drawn from the chart above:
# - The ratings for products in the categories of Toys & Games, Car & Motorbike, and Health & Personal Care range from 3.75 to 4.375. All Home Improvement and Office Products have a minimum rating of 4.0.
#
# - A significant number of Computer & Accessories and Electronics products have ratings ranging from 3.6 to 4.6. While these categories contain products with both high ratings, such as 5.0, and low ratings, as low as 2.75.
#
# - ignificantly, the Home & Kitchen products exhibit a wide range of ratings, ranging from a high of 4.75 to a low of 2.0, which is the lowest rating among all the products in this dataset. Nevertheless, the majority of the products in this category are typically priced between 3.8 and 4.6.

# %% [markdown]
# ---
# ### Question 4: Which categories are most often discounted with high discount percentage(>50%) ?
#
# Meaning: Customer can wait to sale event to buy their wishlist at the lowest possible price if the product is in the category of regular discounts?

# %%
# choose necessary columns to answer this question
regularBigSale = amazon_df.copy()[['sub_category','discount_percentage']]

regularBigSale.head()
# Out:
#   sub_category  discount_percentage
# 0    USBCables                 0.64
# 1    USBCables                 0.43
# 2    USBCables                 0.90
# 3    USBCables                 0.53
# 4    USBCables                 0.61

# %%
# Calculate mean discount percentage for each category
category_means = regularBigSale.groupby('sub_category')['discount_percentage'].mean().reset_index()

# Filter out categories with mean of discount percentage less than 50%
filtered_categories = category_means[category_means['discount_percentage'] >= 0.5]['sub_category']

# Get top 30 categories with the highest number of products
category_counts = regularBigSale[regularBigSale['sub_category'].isin(filtered_categories)].groupby('sub_category').size().sort_values(ascending=False)
top_categories = category_counts.head(30).index


# Filter out products that belong to the top 30 categories
filtered_data = regularBigSale[regularBigSale['sub_category'].isin(top_categories)]

# %%
# Visualize the result
plt.figure(figsize=(20, 10))
sns.boxplot(y='sub_category', x='discount_percentage', data=filtered_data.explode('discount_percentage'), palette='turbo')
plt.title('Boxplot of Discount Percentage by Category (Mean >= 0.5, Top 30 Categories)')
plt.xlabel('Discount Percentage')
plt.ylabel('Category')

plt.axvline(x=0.5, color='red', linestyle='--', label='Threshold at 0.5')
plt.show()

# %% [markdown]
# ### Answering the question:
# - This plot depicts the top 30 categories with the most number of discounts of 50% or more, as well as the history of their discount percentages in the past.
# - If a user wants to buy a product on the list, they can consider waiting for a sale event to get a reasonable price, especially for technology accessories, kitchenware, etc., or simply wait for the product if it is not urgent and the current price is too high.

# %% [markdown]
# ----
# ## Reflection
# 1. Pain
# - We also encountered some problems when completing this project: Choosing data is difficult because there is too much data available on different platforms, asking questions also requires knowledge of the field. that we learn about
# - The presentation time is too short, making it difficult to implement ideas
# - Some information must be omitted so that the presentation fits within the set time
#
# 2. Gain
# - Improve thinking and problem solving
# - Knowing how to use data science to uncover information that can help answer problems and provide insightful information
# - Improve coding skills
#
# *If we have more time we will:*
# - Build a Machine Learning model to predict discounted_price base on those numerical attributes, and add more meaningfull questions
# - Read more document to improve domain knowledge
# - To better comprehend data, find out more about how to show and interpret charts.

# %% [markdown]
# ---
# ## Reference
# - boxplot: https://en.wikipedia.org/wiki/Box_plot
# - seaborn boxplot: https://seaborn.pydata.org/generated/seaborn.boxplot.html
